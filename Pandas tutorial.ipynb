# %% [markdown]
# **Introduction to Python Pandas**

# %% [markdown]
# Dataset column names:
#
# 1. Region
# 2. Country
# 3. Item Type
# 4. Sales Channel
# 5. Order Priority
# 6. Order Date
# 7. Order ID
# 8. Ship Date
# 9. Units Sold
# 10. Unit Price
# 11. Unit Cost
# 11. Total Revenue
# 12. Total Cost
# 13. Total Profit

# %%
#Import pandas library for data analysis
import pandas as pd

# %%
#save the file path in a variable
csv_path=r"C:\Users\Shahlo\Desktop\code related\IBM Data Science\Course 4\sales.csv"

# %%
#save the contents of the file as a dataframe, and skip null cells
df = pd.read_csv(csv_path, error_bad_lines=False)

# %%
#see the first 5 rows of the file
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
#Let's access the "Country" column
country = df[["Country"]]
country
# Out:
#                              Country
# 0                             Tuvalu
# 1                            Grenada
# 2                             Russia
# 3              Sao Tome and Principe
# 4                             Rwanda
# 5                    Solomon Islands
# 6                             Angola
# 7                       Burkina Faso
# 8              Republic of the Congo
# 9                            Senegal
# 10                        Kyrgyzstan
# 11                        Cape Verde
# 12                        Bangladesh
# 13                          Honduras
# 14                          Mongolia
# 15                          Bulgaria
# 16                         Sri Lanka
# 17                          Cameroon
# 18                      Turkmenistan
# 19                        East Timor
# 20                            Norway
# 21                          Portugal
# 22                          Honduras
# 23                       New Zealand
# ...

# %%
#Let's get the same column as a series or as 1-D dataframe
country = df["Country"]
country
# Out:
# 0                               Tuvalu
# 1                              Grenada
# 2                               Russia
# 3                Sao Tome and Principe
# 4                               Rwanda
# 5                      Solomon Islands
# 6                               Angola
# 7                         Burkina Faso
# 8                Republic of the Congo
# 9                              Senegal
# 10                          Kyrgyzstan
# 11                          Cape Verde
# 12                          Bangladesh
# 13                            Honduras
# 14                            Mongolia
# 15                            Bulgaria
# 16                           Sri Lanka
# 17                            Cameroon
# 18                        Turkmenistan
# 19                          East Timor
# 20                              Norway
# 21                            Portugal
# 22                            Honduras
# 23                         New Zealand
# ...

# %%
#Get the column as a dataframe
country=type(df[["Country"]])
country
# Out:
# pandas.core.frame.DataFrame

# %%
#Let's access multiple columns
x = df[["Country", "Units Sold", "Total Profit"]]
x
# Out:
#                              Country  Units Sold  Total Profit
# 0                             Tuvalu        9925     951410.50
# 1                            Grenada        2804     248406.36
# 2                             Russia        1779     224598.75
# 3              Sao Tome and Principe        8102      19525.82
# 4                             Rwanda        5062     639077.50
# 5                    Solomon Islands        2974     285087.64
# 6                             Angola        4187     693911.51
# 7                       Burkina Faso        8082     510216.66
# 8              Republic of the Congo        6070     152114.20
# 9                            Senegal        6593     584073.87
# 10                        Kyrgyzstan         124       7828.12
# 11                        Cape Verde        4168     306097.92
# 12                        Bangladesh        8263     606834.72
# 13                          Honduras        8974    1487261.02
# ...

# %%
#Let's access one cell by using iloc function. In this case we will get the first item on the first row and the first column. Remember to start the count from 0.
df.iloc[0,0]
# Out:
# 'Australia and Oceania'

# %%
#Get the item from the first row and the third column
df.iloc[0,2]
# Out:
# 'Baby Food'

# %%
#Access the column using the name. This time use loc function
df.loc[4, 'Country']
# Out:
# 'Rwanda'

# %%
df.loc[2, "Units Sold"]
# Out:
# 1779

# %%
#Let's perform slicing using both the index and the name of the column. First 2 rows and first 3 rows
df.iloc[0:2, 0:3]
# Out:
#                               Region  Country  Item Type
# 0              Australia and Oceania   Tuvalu  Baby Food
# 1  Central America and the Caribbean  Grenada     Cereal

# %%
# Slicing the dataframe using name

df.loc[0:2, 'Country':'Sales Channel']
# Out:
#    Country        Item Type Sales Channel
# 0   Tuvalu        Baby Food       Offline
# 1  Grenada           Cereal        Online
# 2   Russia  Office Supplies       Offline

# %%
#Quiz on Dataframe

# %%
#1. Use variable y to store column "Region" as dataframe. Write your code below and press Shift+Enter to execute

# %%
#2. Assign the variable q to the dataframe that is made up of the column "Item Type" and "Unit Price":

# %%
#3. Access the 5th row and the 4th column of df
